# %% [markdown]
# # CROP ADVISOR
#
# - #### **Name   :** Kalash Shah
# - #### **Roll No:** 40

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("crop.csv")
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %% [markdown]
# - **N (Nitrogen) :** Ratio of Nitrogen content in soil
# - **P (Phosphorous) :** Ratio of Phosphorous content in soil
# - **K (Potassium) :** Ratio of Potassium content in soil
# - **Temperature :** Temperature in degrees Celsius
# - **Humidity :** Relative humidity in %
# - **pH :** pH value of the soil
# - **Rainfall :** Rainfall in mmin mm
# <br>

# %%
df['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
print(df.dtypes)
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# dtype: object

# %%
# Check foor missing values
df.isna().sum()
# using isnull() function   
#df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %% [markdown]
# ## Understanding the average characteristics of different types of crops

# %%
label_groupby = df.groupby('label').mean().reset_index()
label_groupby
#blackgram - udad dal
#chickpea - kabuli chana
#kidneybeans - rajma
#lentil - dal
# mothbeans - matki dal
# mungbean - moong
# muskmelon - tatti
# pegionpeas - towar
# pomegranate - dadam
# Out:
#           label       N       P       K  temperature   humidity        ph  \
# 0         apple   20.80  134.22  199.89    22.630942  92.333383  5.929663
# 1        banana  100.23   82.01   50.05    27.376798  80.358123  5.983893
# 2     blackgram   40.02   67.47   19.24    29.973340  65.118426  7.133952
# 3      chickpea   40.09   67.79   79.92    18.872847  16.860439  7.336957
# 4       coconut   21.98   16.93   30.59    27.409892  94.844272  5.976562
# 5        coffee  101.20   28.74   29.94    25.540477  58.869846  6.790308
# 6        cotton  117.77   46.24   19.56    23.988958  79.843474  6.912675
# 7        grapes   23.18  132.53  200.11    23.849575  81.875228  6.025937
# 8          jute   78.40   46.86   39.99    24.958376  79.639864  6.732778
# 9   kidneybeans   20.75   67.54   20.05    20.115085  21.605357  5.749411
# 10       lentil   18.77   68.36   19.41    24.509052  64.804785  6.927932
# 11        maize   77.76   48.44   19.79    22.389204  65.092249  6.245190
# ...

# %%
# Size of my dataset
print(df.size)
# Out:
# 17600

# %% [markdown]
# ### Statistics of dataset

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %% [markdown]
# <br>

# %% [markdown]
# # **Visualization of Dataset**

# %% [markdown]
# ###  Histogram for the data of soil metrics (N, P, K, and ph)

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

colors = ['skyblue', 'lightgreen', 'orange', 'pink']

# Histogram for N
axes[0, 0].hist(df["N"], bins=10, color=colors[0], edgecolor='black')
axes[0, 0].set_xlabel("N")
axes[0, 0].set_ylabel("Frequency")
axes[0, 0].set_title("Nitrogen (N)")

# Histogram for P
axes[0, 1].hist(df["P"], bins=10, color=colors[1], edgecolor='black')
axes[0, 1].set_xlabel("P")
axes[0, 1].set_ylabel("Frequency")
axes[0, 1].set_title("Phosphorous (P)")

# Histogram for K
axes[1, 0].hist(df["K"], bins=10, color=colors[2], edgecolor='black')
axes[1, 0].set_xlabel("K")
axes[1, 0].set_ylabel("Frequency")
axes[1, 0].set_title("Potassium (K)")

# Histogram for ph
axes[1, 1].hist(df["ph"], bins=10, color=colors[3], edgecolor='black')
axes[1, 1].set_xlabel("pH")
axes[1, 1].set_ylabel("Frequency")
axes[1, 1].set_title("Acidity (pH)")

# Add spacing between subplots
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Histogram for weather data (temperature, humidity and rainfall)

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

colors = ['lavender', 'y', 'cornflowerblue']

# Histogram for Temperature
axes[0, 0].hist(df["temperature"], bins=10, color=colors[0], edgecolor='black')
axes[0, 0].set_xlabel("Temperature (°C)")
axes[0, 0].set_ylabel("Frequency")
axes[0, 0].set_title("Temperature (°C)")

# Histogram for Humidity
axes[0, 1].hist(df["humidity"], bins=10, color=colors[1], edgecolor='black')
axes[0, 1].set_xlabel("Relative Humidity (%)")
axes[0, 1].set_ylabel("Frequency")
axes[0, 1].set_title("Relative Humidity (%)")

# Histogram for Rainfall
axes[1, 0].hist(df["rainfall"], bins=10, color=colors[2], edgecolor='black')
axes[1, 0].set_xlabel("Rainfall (mm)")
axes[1, 0].set_ylabel("Frequency")
axes[1, 0].set_title("Rainfall (mm)")

# Set the visibility of the axes of the last two plots to False
axes[1, 1].axis('off')

# Add spacing between subplots
plt.tight_layout()

plt.show()

# %% [markdown]
# ### For Nitrogen

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=45)
sns.boxplot(data=df, x = 'label', y = 'N')
plt.grid()
plt.show()

# %% [markdown]
# - **High requarment of Nitrogen in soil**: banana, watermelon, muskmelon, cotton, coffee
# - Most crops do not need much Nitrogen
# <br>

# %% [markdown]
# ### For Phosphorous

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=45)
sns.boxplot(data=df, x = 'label', y = 'P')
plt.grid()
plt.show()

# %% [markdown]
# - **High requirement of Phosphorous in soil** : grapes, apple
# - **low Phosphorous in soil** : pomegranate, watermelon, muskmelon, orange, coconut
# <br>

# %% [markdown]
# ### For Potassium

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=45)
sns.boxplot(data=df, x = 'label', y = 'P')
plt.grid()
plt.show()

# %% [markdown]
# - **High requirement of Potassium in soil** : grapes, apple
# - **Lowest requirement of Potassium in soil** : orange
# - **Low requirement of Potassium in soil for 9 crops** : less than 25
# <br>

# %% [markdown]
# ### For Temperature

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=45)
sns.boxplot(data=df, x = 'label', y = 'temperature')
plt.grid()
plt.show()

# %% [markdown]
# - **Crops that are not sensitive to extreme temperature changes** : pigeonpeas, grapes, orange, papaya
# - More crops planing in range 15-35 degree
# <br>

# %% [markdown]
# ### For Humidity

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=45)
sns.boxplot(data=df, x = 'label', y = 'humidity')
plt.grid()
plt.show()

# %% [markdown]
# - More crops planing with humidity of more than 60
# - **Low humidity** : chickpea, kidneybeans
# - **Wide range of humidity** : pigeonpeas, mothbeans
# <br>

# %% [markdown]
# ### For pH

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=45)
sns.boxplot(data=df, x = 'label', y = 'ph')
plt.grid()
plt.show()

# %% [markdown]
# - **Crops that range of PH in low** : papaya, kidneybeans
# - **Many changes in PH** : mothbeans
# <br>

# %% [markdown]
# ### For Rainfall

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=45)
sns.boxplot(data=df, x = 'label', y = 'rainfall')
plt.grid()
plt.show()

# %% [markdown]
# - **High amount of rainfall** : rice
# - **Low amount of rainfall** : muskmelon
# <br>

# %% [markdown]
# ## Top most soil Metrics and Weather Data Requiring Crops

# %%
for i in label_groupby.columns[1:]:
    print(f'Top five Most {i} requiring crops;')
    print("")
    for j,k in label_groupby.sort_values(by=i, ascending=False)[:5][['label',i]].values:
        print(f'{j} -->{k}')
    print(f'________________________________________________________')
    print("")
# Out:
# Top five Most N requiring crops;
#
# cotton -->117.77
# coffee -->101.2
# muskmelon -->100.32
# banana -->100.23
# watermelon -->99.42
# ________________________________________________________
#
# Top five Most P requiring crops;
#
# apple -->134.22
# grapes -->132.53
# banana -->82.01
# lentil -->68.36
# chickpea -->67.79
# ________________________________________________________
#
# Top five Most K requiring crops;
#
# grapes -->200.11
# apple -->199.89
# chickpea -->79.92
# watermelon -->50.22
# muskmelon -->50.08
# ________________________________________________________
#
# Top five Most temperature requiring crops;
#
# papaya -->33.7238587388
# mango -->31.2087701513
# blackgram -->29.9733396789
# muskmelon -->28.663065756
# mungbean -->28.5257747353
# ________________________________________________________
#
# Top five Most humidity requiring crops;
#
# coconut -->94.84427180610001
# papaya -->92.4033876826
# muskmelon -->92.34280196089999
# apple -->92.3333828756
# ...

# %% [markdown]
# ## Bottom soil Metrics and Weather Data Requiring Crops

# %%
for i in label_groupby.columns[1:]:
    print(f'Bottom five {i} requiring crops;')
    print("")
    for j,k in label_groupby.sort_values(by=i)[:5][['label',i]].values:
        print(f'{j} -->{k}')
    print(f'________________________________________________________')
    print("")
# Out:
# Bottom five N requiring crops;
#
# lentil -->18.77
# pomegranate -->18.87
# orange -->19.58
# mango -->20.07
# pigeonpeas -->20.73
# ________________________________________________________
#
# Bottom five P requiring crops;
#
# orange -->16.55
# coconut -->16.93
# watermelon -->17.0
# muskmelon -->17.72
# pomegranate -->18.75
# ________________________________________________________
#
# Bottom five K requiring crops;
#
# orange -->10.01
# blackgram -->19.24
# lentil -->19.41
# cotton -->19.56
# maize -->19.79
# ________________________________________________________
#
# Bottom five temperature requiring crops;
#
# chickpea -->18.8728467519
# kidneybeans -->20.1150846851
# pomegranate -->21.837841721999997
# maize -->22.3892039102
# apple -->22.6309424132
# ________________________________________________________
#
# Bottom five humidity requiring crops;
#
# chickpea -->16.8604394237
# kidneybeans -->21.6053567295
# pigeonpeas -->48.0616330847
# mango -->50.1565726953
# ...

# %% [markdown]
# # Prediction

# %% [markdown]
# ### Divide Dataset to X and Y(target)

# %%
X = df.drop('label',axis=1)    # Dataframe, independent variable
Y= df['label']              # Series, Dependent Variable

# %% [markdown]
# ### Train and Test Splitting

# %%
from sklearn.model_selection import train_test_split

# Assuming X is a numpy array of integers and Y is a list of strings
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Checking the Accuracy of Different Algorithims

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

models = {
    'logistic regression': LogisticRegression(),
    'k-nearest neighbors': KNeighborsClassifier(),
    'decision tree': DecisionTreeClassifier(),
    'random forest': RandomForestClassifier(),
}

accuracy_scores = []
for name, md in models.items():
    md.fit(X_train, y_train)
    ypred = md.predict(X_test)
    accuracy = accuracy_score(y_test, ypred)
    accuracy_scores.append(accuracy)
    print(f"{name} with accuracy: {accuracy}")
    print("")
# Out:
# logistic regression with accuracy: 0.9454545454545454
#
# k-nearest neighbors with accuracy: 0.9704545454545455
#
# decision tree with accuracy: 0.9818181818181818
#
# random forest with accuracy: 0.9931818181818182

# %% [markdown]
# ### Plotting the values Accuracy

# %%
plt.figure(figsize=(10, 6))
plt.bar(models.keys(), accuracy_scores, color='green')
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison of Different Models')
plt.ylim(0, 1)  # Set y-axis limit between 0 and 1 for accuracy scores
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ## Traning the Model Using Random Forest

# %%
clf = RandomForestClassifier()
clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test)

# %% [markdown]
# ## Comparing the values of Testing and Prediction

# %%
diff = pd.DataFrame({'y_test':y_test,'y_predict':y_pred})
diff
# Out:
#           y_test   y_predict
# 1451   muskmelon   muskmelon
# 1334  watermelon  watermelon
# 1761      papaya      papaya
# 1735      papaya      papaya
# 1576       apple       apple
# ...          ...         ...
# 59          rice        rice
# 71          rice        rice
# 1908      cotton      cotton
# 1958      cotton      cotton
# 482   pigeonpeas  pigeonpeas
#
# [440 rows x 2 columns]

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(clf,open('pipe.pkl','wb'))

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.5.2
